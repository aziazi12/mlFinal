# %%
import os
import matplotlib.pyplot as plt


# Check if curve graphs exist. If they do then display them
if os.path.exists('learning_curve_model_1.png'):
    # Read the image files
    image1 = plt.imread('learning_curve_model_1.png')

    # Display the images
    plt.imshow(image1)
    plt.axis('off')
    plt.show()

if os.path.exists('learning_curve_model_2.png'):
    # Read the image files
    image1 = plt.imread('learning_curve_model_2.png')

    # Display the images
    plt.imshow(image1)
    plt.axis('off')
    plt.show()
